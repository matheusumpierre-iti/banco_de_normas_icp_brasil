# %%
import os

# %%
os.listdir('testes/teste_batch')
# Out:
# ['DOC-ICP-01.01_v.4.2_PADROES_ALGORITMOS_CRIPTOGRAFICOS_ICP-BRASIL com marcacoes.pdf',
#  'DOC-ICP-01.01_v.4.2_PADROES_ALGORITMOS_CRIPTOGRAFICOS_ICP-BRASIL.pdf',
#  'DOC-ICP-03.01_v.4.0_CARACTERISCAS_MINIMAS_SEGURANCA_AR_ICP-BRASIL.pdf',
#  'DOC-ICP-03.02_v.2.0_REQUISITOS_MÍNIMOS_SEGURANÇA_PSBIO.pdf',
#  'DOC-ICP-04.01_v.5.0_ATRIBUICAO_OID_ICP-BRASIL.pdf',
#  'DOC-ICP-05.01_v.2.0_PROCEDIMENTO_IDENTIDADE_SERVICO_EXTERIOR_BRASILEIRO_MISSAO_PERMANENTE_EXTERIOR.pdf',
#  'DOC-ICP-05.02_v.4.0_PROCEDIMENTOS_IDENTIFICACAO_COMUNICACAO_IRREGULARIDADES_PROCESSO_EMISSAO_C.D_ICP-BRASIL.pdf',
#  'DOC-ICP-05.04_v.3.0_PROCEDIMENTOS_GERENCIAMENTO_CHAVE_SIMETRICA_GERACAO_IDN.pdf',
#  'DOC-ICP-05.05_v.2.0_PROCEDIMENTO_IDENTIFICACAO_REQUERENTES_C.D_VIDEOCONFERENCIA.pdf',
#  'DOC-ICP-07.01_v.2.0_PROCEDIMENTOS_OBTENCAO_HORA_UTC_ICP-BRASIL.pdf',
#  'DOC-ICP-07_v.3.0_DIRETRIZES_SINCRONIZACAO-FREQUENCIA_TEMPO_ICP-BRASIL Anexo Resolução 175.pdf',
# ...
