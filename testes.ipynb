# %%
from docx import Document
import pypandoc
import pdfplumber
from bs4 import BeautifulSoup
import lxml

# %%
documento = r'C:\Users\matheus.umpierre\Projetos\lexml_icp_brasil_gitlab\lex_icp_brasil\testes\Resolucao178_DOC-ICP-03.pdf'

pdf = pdfplumber.open(documento)

# %%
pdf.pages[0].to_dict()
# Out:
# {'page_number': 1,
#  'initial_doctop': 0,
#  'rotation': 0,
#  'cropbox': (0.0, 0.0, 595.32, 841.92),
#  'mediabox': (0.0, 0.0, 595.32, 841.92),
#  'bbox': (0.0, 0.0, 595.32, 841.92),
#  'width': 595.32,
#  'height': 841.92,
#  'chars': [{'matrix': (12.0, 0.0, 0.0, 12.0, 133.2, 739.68),
#    'fontname': 'BHGPWB+TimesNewRomanPSMT',
#    'adv': 0.667,
#    'upright': True,
#    'x0': 133.2,
#    'y0': 735.996,
#    'x1': 141.20399999999998,
#    'y1': 747.996,
#    'width': 8.00399999999999,
#    'height': 12.0,
#    'size': 12.0,
#    'mcid': 0,
#    'tag': 'P',
#    'object_type': 'char',
#    'page_number': 1,
#    'ncs': 'DeviceGray',
#    'text': 'R',
#    'stroking_color': (0,),
#    'non_stroking_color': (0,),
#    'top': 93.92399999999998,
#    'bottom': 105.92399999999998,
#    'doctop': 93.92399999999998},
#   {'matrix': (12.0, 0.0, 0.0, 12.0, 141.23999999999998, 739.68),
#    'fontname': 'BHGPWB+TimesNewRomanPSMT',
#    'adv': 0.611,
#    'upright': True,
# ...
